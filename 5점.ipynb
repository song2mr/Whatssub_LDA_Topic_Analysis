# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from gensim.models.ldamodel import LdaModel
from gensim.models.callbacks import CoherenceMetric
from gensim import corpora
from gensim.models.callbacks import PerplexityMetric
sns.set(font="Malgun Gothic", 
        rc={"axes.unicode_minus":False},
        style='darkgrid')

# %%
Data= pd.read_excel('(2022-11-21)_왓섭.xlsx')
Data=Data[Data['별점']==5]

# %% [markdown]
# ## LDA
# 참고: https://happy-obok.tistory.com/5 / https://dacon.io/competitions/official/235590/codeshare/1078

# %%
from gensim import corpora

# %%
#특정 열의 값 별 몇 개의 행이 있는지 세기

element_count = {}

for item in Data['별점']:
    element_count.setdefault(item,0)
    element_count[item] += 1
    
count = pd.DataFrame.from_dict(element_count, orient = 'index',columns=["count"])
count
# Out:
#    count
# 5    205

# %%
#데이터 프레임의 'text' 열의 값들을 str 형식으로 바꾸기
Data.별점 = Data.별점.astype(str)

#text와 timestamp 열을 기준으로 중복된 데이터를 삭제, inplace : 데이터 프레임을 변경할지 선택(원본을 대체)
#Data.drop_duplicates(subset=['text','timestamp'], inplace=True)

#한글이 아니면 빈 문자열로 바꾸기
Data['리뷰내용'] = Data['리뷰내용'].str.replace('[^ㄱ-ㅎㅏ-ㅣ가-힣]',' ',regex=True)

#빈 문자열 NAN 값으로 바꾸기
Data = Data.replace({'': np.nan})
Data = Data.replace(r'^\s*$', None, regex=True)

#NAN 이 있는 행은 삭제
Data.dropna(how='any', inplace=True)

#인덱스 차곡차곡
Data = Data.reset_index (drop = True)

#데이터 프레임에 null 값이 있는지 확인
print(Data.isnull().values.any())
# Out:
# False

# %%
#텍스트 데이터를 리스트로 변환
Data_list=Data['리뷰내용'].values.tolist()

# %%
#pip install konlpy
#konlpy 설치

# %%
from konlpy.tag import Kkma
kkma=Kkma()
#https://mr-doosun.tistory.com/22

# %%
#텍스트 데이터를 리스트로 변환
Data_list=Data.리뷰내용.values.tolist()
#리스트를 요소별로(트윗 하나) 가져와서 명사만 추출한 후 리스트로 저장
data_word=[]
for i in range(len(Data_list)):
    try:
        data_word.append(kkma.nouns(Data_list[i]))
    except Exception as e:
        continue

#data_word

# %%
#pip install gensim

from collections import Counter
from konlpy.tag import Okt
okt = Okt()
# %matplotlib inline
import matplotlib.pyplot as plt
import re 
import gensim
from gensim import corpora, models
from gensim.models import CoherenceModel

# %% [markdown]
# mallet 설정: https://github.com/RaRe-Technologies/gensim/issues/2163

# %%
import os
os.environ.update({'MALLET_HOME':r'C:/mallet-2.0.8/'})

mallet_path = 'C:/mallet-2.0.8/bin/mallet'

# %%
id2word=corpora.Dictionary(data_word)
id2word.filter_extremes(no_below = 3) #3회 이하로 등장한 단어는 삭제
texts = data_word
corpus=[id2word.doc2bow(text) for text in texts]

#mallet_path = 'C:\\mallet-2.0.8\\bin\\mallet'
ldamallet = gensim.models.wrappers.LdaMallet(mallet_path, corpus=corpus, num_topics=10, id2word=id2word)

# %%
coherence_model_ldamallet = CoherenceModel(model=ldamallet, texts=texts, dictionary=id2word, coherence='c_v')
coherence_ldamallet = coherence_model_ldamallet.get_coherence()


def compute_coherence_values(dictionary, corpus, texts, limit, start=4, step=2):

    coherence_values = []
    model_list = []
    for num_topics in range(start, limit, step):
        model = gensim.models.wrappers.LdaMallet(mallet_path, corpus=corpus, num_topics=num_topics, id2word=id2word)
        model_list.append(model)
        coherencemodel = CoherenceModel(model=model, texts=data_word, dictionary=dictionary, coherence='c_v')
        coherence_values.append(coherencemodel.get_coherence())

    return model_list, coherence_values

# %%
# Can take a long time to run.
model_list, coherence_values = compute_coherence_values(dictionary=id2word, corpus=corpus, texts=texts, start=4, limit=21, step=2)

# %%
limit=21; start=4; step=2;
x = range(start, limit, step)
topic_num = 0
count = 0
max_coherence = 0
for m, cv in zip(x, coherence_values):
    print("Num Topics =", m, " has Coherence Value of", cv)
    coherence = cv
    if coherence >= max_coherence:
        max_coherence = coherence
        topic_num = m
        model_list_num = count   
    count = count+1

        
# Select the model and print the topics
optimal_model = model_list[model_list_num]
model_topics = optimal_model.show_topics(formatted=False)
#print(optimal_model.print_topics(num_words=10))








def format_topics_sentences(ldamodel=optimal_model, corpus=corpus, texts=texts):
    # Init output
    sent_topics_df = pd.DataFrame()

    # Get main topic in each document
    #ldamodel[corpus]: lda_model에 corpus를 넣어 각 토픽 당 확률을 알 수 있음
    for i, row in enumerate(ldamodel[corpus]):
        row = sorted(row, key=lambda x: (x[1]), reverse=True)
        # Get the Dominant topic, Perc Contribution and Keywords for each document
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:  # => dominant topic
                wp = ldamodel.show_topic(topic_num,topn=10)
                topic_keywords = ", ".join([word for word, prop in wp])
                sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
            else:
                break
    sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']
    print(type(sent_topics_df))

    # Add original text to the end of the output
    #contents = pd.Series(texts)
    #sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
    sent_topics_df = pd.concat([sent_topics_df, Data['리뷰내용'],Data['별점']], axis=1)
    return(sent_topics_df)
# Out:
# Num Topics = 4  has Coherence Value of 0.440955018176206
# Num Topics = 6  has Coherence Value of 0.4846533610568417
# Num Topics = 8  has Coherence Value of 0.5569005706760448
# Num Topics = 10  has Coherence Value of 0.5593947511401083
# Num Topics = 12  has Coherence Value of 0.5571978582436409
# Num Topics = 14  has Coherence Value of 0.563285675565644
# Num Topics = 16  has Coherence Value of 0.587024471481259
# Num Topics = 18  has Coherence Value of 0.5864388406686643
# Num Topics = 20  has Coherence Value of 0.5791274379439552

# %%
df_topic_sents_keywords = format_topics_sentences(ldamodel=optimal_model, corpus=corpus, texts=Data_list)

# Format
df_topic_tweet = df_topic_sents_keywords.reset_index()
df_topic_tweet.columns = ['Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords','', '리뷰내용','별점']

# Show각 문서에 대한 토픽
#df_dominant_topic=df_dominant_topic.sort_values(by=['Dominant_Topic'])
#df_topic_tweet



# Group top 5 sentences under each topic
sent_topics_sorteddf_mallet = pd.DataFrame()

sent_topics_outdf_grpd = df_topic_sents_keywords.groupby('Dominant_Topic')

for i, grp in sent_topics_outdf_grpd:
    sent_topics_sorteddf_mallet = pd.concat([sent_topics_sorteddf_mallet, 
                                             grp.sort_values(['Perc_Contribution'], ascending=[0]).head(1)], 
                                            axis=0)

# Reset Index    
sent_topics_sorteddf_mallet.reset_index(drop=True, inplace=True)


topic_counts = df_topic_sents_keywords['Dominant_Topic'].value_counts()
topic_counts.sort_index(inplace=True)

topic_contribution = round(topic_counts/topic_counts.sum(), 4)
topic_contribution

lda_inform = pd.concat([sent_topics_sorteddf_mallet, topic_counts, topic_contribution], axis=1)
lda_inform.columns=["Topic_Num", "Topic_Perc_Contrib", "Keywords", '리뷰내용','별점',"Num_Documents", "Perc_Documents"]
lda_inform = lda_inform[["Topic_Num","Keywords","Num_Documents","Perc_Documents"]]
lda_inform
#lda_inform.Topic_Num = lda_inform.Topic_Num.astype(int)
lda_inform['Topic_Num'] =lda_inform['Topic_Num'] +1
lda_inform.Topic_Num = lda_inform.Topic_Num.astype(str)
lda_inform['Topic_Num'] =lda_inform['Topic_Num'].str.split('.').str[0]
df_topic_tweet['Dominant_Topic'] =df_topic_tweet['Dominant_Topic'] +1
df_topic_tweet.Dominant_Topic = df_topic_tweet.Dominant_Topic.astype(str)
df_topic_tweet['Dominant_Topic'] =df_topic_tweet['Dominant_Topic'].str.split('.').str[0]
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
lda_inform.to_csv ("lda_inform5.csv",encoding='ANSI', index = None)
lda_inform
# Out:
#      Topic_Num                                   Keywords  Num_Documents  \
# 0.0          1  관리, 왓섭, 고객, 이거, 무료, 왓섭으, 해지, 여기저기, 등록, 관련             29
# 1.0          2      한눈, 추천, 유용, 생활, 금액, 제가, 완전, 정, 리뷰, 어플             20
# 2.0          3         돈, 확인, 내, 안내, 시간, 이체, 일, 덕분, 꿀, 설명             16
# 3.0          4   가능, 연동, 구독서비스, 눈, 이용, 카카오, 도움, 신경, 다운, 페             10
# 4.0          5    친절, 사용, 상담, 문제, 체크, 센터, 고객센터, 뿐, 고객, 불편             17
# 5.0          6         앱, 분, 처리, ㅎ, 하나, 저, 입력, 직관적, 전, 방법             15
# 6.0          7      지출, 한번, 고정, 추가, 월, 통신비, 달, 요즘, 정확, 응대             16
# 7.0          8       구독, 안, 정보, 구, 자동이체, 계좌, 시, 개, 필요, 생각              6
# 8.0          9     정기, 정기결제, 거, 다, 만족, 상담, 번호, 필요, 피드백, 페             11
# 9.0         10       감사, 거, 결제, 내역, 기능, 가입, 독, 중인, 디자인, 데              9
# 10.0        11      수, 편리, 기대, 점, 처음, 다양, 왓섭, 도움, 가계부, 광고              6
# 11.0        12        플, 문의, 정리, 등, 적금, 대응, 뱅크, 느낌, 친절, 듯              8
# 12.0        13   해결, 때, 카드, 앞, 개발자, 은행, 업데이트, 비밀번호, ㅠ, 설치             11
# 13.0        14    결제, 서비스, 등록, 간편, 파악, 얼마, 개발, 세상, 어플, 확인              6
# 14.0        15       편리, 구독, 생각, 자동, 관리, 인증서, 중, 요금, 눈, 건             16
# 15.0        16   서비스, 사용, 최고, 정기적, 왓섭, 수정, 내용, 관련, 광고, 응대              9
#
#       Perc_Documents
# 0.0           0.1415
# 1.0           0.0976
# 2.0           0.0780
# 3.0           0.0488
# 4.0           0.0829
# 5.0           0.0732
# 6.0           0.0780
# 7.0           0.0293
# 8.0           0.0537
# 9.0           0.0439
# 10.0          0.0293
# 11.0          0.0390
# 12.0          0.0537
# 13.0          0.0293
# 14.0          0.0780
# 15.0          0.0439

# %% [markdown]
# ## 시각화

# %%
#pip install wordcloud-1.7.0-cp38-cp38-win_amd64.whl

# %%
import pickle
import pyLDAvis.gensim_models as gensimvis
import pyLDAvis
from gensim.models.coherencemodel import CoherenceModel
import matplotlib.pyplot as plt

# %%
data_word
# Out:
# [['장점',
#   '소액',
#   '지출',
#   '수',
#   '거',
#   '달',
#   '체크',
#   '가능',
#   '가계부',
#   '가계부등',
#   '등',
#   '지출내역',
#   '내역',
#   '정리',
#   '때',
#   '유용',
#   '처음',
#   '로그',
#   '로그인',
#   '인',
#   '인증',
#   '문의',
#   '응대',
#   '친절',
#   '서비스',
#   '해결',
#   '단점',
#   '부분',
#   '있닐',
#   '있닐대',
#   '대',
#   '시간',
#   '약간',
#   '꺼',
#   '문제',
#   '플'],
#  ['디자인',
#   '기능',
#   '생각',
#   '광고',
#   '광고보고',
#   '보고',
#   '거',
#   '거라',
#   '라',
#   '연동',
#   '정기',
#   '정기결제',
#   '결제',
#   '많으',
#   '예상',
#   '외의',
#   '기능성',
#   '로딩',
#   '초',
#   '초',
#   '한국인',
#   '불편',
#   '로딩속',
#   '전반적',
#   '만족',
#   '보안',
#   '신경'],
#  ['안녕',
#   '플',
#   '직관적',
#   '고객',
#   '고객경험개선',
#   '경험',
#   '개선',
#   '도움',
#   '처음',
#   '공인',
#   '공인인증서',
#   '인증서',
#   '로그',
#   '로그인',
#   '인',
#   '시도',
#   '때',
#   '계속',
#   '비밀',
#   '비밀번호',
#   '번호',
#   '오류',
#   '구',
#   '짜증',
#   '하나',
#   '은행',
#   '은행앱',
#   '앱',
#   '이상',
#   '영문',
#   '입력',
#   '입력간',
#   '간',
#   '대문자',
#   '거',
#   '그거',
#   '때문',
#   '은행어플',
#   '별도',
#   '입력기',
#   '기'],
#  ['다',
#   '동일',
#   '계좌',
#   '보험',
#   '자동',
#   '자동이체',
#   '이체',
#   '지금',
#   '둘',
#   '중',
#   '건',
#   '세부',
#   '내역',
#   '확인',
#   '수',
#   '이것',
#   '합산',
#   '금액',
#   '럭',
#   '럭시노트',
#   '시',
#   '노트',
#   '사용',
#   '사용중',
#   '업',
#   '업데이트',
#   '데이트',
#   '다운',
#   '가기',
#   '강',
#   '강종',
#   '종',
#   '현상',
#   '발생',
#   '가계부',
#   '날',
#   '수정',
#   '해결',
#   '플',
#   '감사',
#   '앞',
#   '개선',
#   '기대',
#   '밤',
#   '리뷰',
#   '불',
#   '불철주야',
#   '철',
#   '주야',
#   '노력',
#   '주시',
#   '왓섭',
#   '최고'],
#  ['달',
#   '무료',
#   '제때',
#   '해지',
#   '돈',
#   'ㅠ',
#   '저',
#   '앱',
#   '등록',
#   '필요',
#   '연동',
#   '디자인',
#   '무엇',
#   '주거래',
#   '주거래통장',
#   '통장',
#   '입출금',
#   '내용',
#   '정리',
#   '지출',
#   '지출관리',
#   '관리',
#   '도움',
#   '앞',
#   '활용'],
#  ['정기',
#   '정기결제',
#   '결제',
#   '관리',
#   '연동',
#   '카드사',
#   '불완전',
#   '내역',
#   '수동',
#   '추가',
#   '수',
#   '기능',
#   '문',
#   '인식',
#   '날짜',
#   '금액',
#   '돈',
#   '후',
#   '지원',
#   '안',
#   '쓰기'],
#  ['업데이트',
#   '필요',
#   '개발자',
#   '개발자분',
#   '분',
#   '내적',
#   '내적친밀감',
#   '친밀감',
#   '문구',
#   '응원',
#   '느낌',
#   'ㅏ',
#   '월',
#   '금액',
#   '카드',
#   '얼마',
#   'ㅠ',
#   '어플',
#   '완벽',
#   '말',
#   '때'],
#  ['구독',
#   '통신비',
#   '적금',
#   '내역',
#   '내역등',
#   '등',
#   '정리',
#   '뿐',
#   '고객',
#   '고객센터',
#   '센터',
#   '에로',
#   '사항',
#   '적극적',
#   '처리'],
#  ['뱅',
#   '뱅셀',
#   '셀',
#   '사용',
#   '달',
#   '정기',
#   '정기구독',
#   '구독',
#   '비용',
#   '왓섭',
#   '초창기',
#   '초창기때',
#   '때',
#   '설치',
#   '앱',
#   '앱사용반응',
#   '반응',
#   '문의',
#   '점심시간',
#   '뷸',
#   '답변',
#   '감사'],
#  ['문의', '대응', '서비스', '서비스면', '면', '만족', '앱', '기능'],
#  ['앱', '가입', '단순', '단순설명', '설명', '진행', '단번', '수', '이제', '후기', '감사'],
#  ['정기',
#   '정기결제내역',
#   '결제',
#   '내역',
#   '다',
#   '글',
#   '글페',
#   '페',
#   '먼트',
#   '유',
#   '유튜브',
#   '튜브',
#   '프리미엄',
#   '거',
#   '구독',
#   '구독항목',
#   '항목',
#   '이름',
#   '사용자',
#   '수정',
#   '수',
#   '구',
#   '구글',
#   '정기결제',
#   '트위',
#   '왓섭',
#   '개'],
#  ['고정', '지출', '한번', '관리', '수', '편리', '다양', '분야', '구독', '서비스'],
#  ['앱',
#   '신경',
#   '눈',
#   '소신',
#   '소신발언',
#   '발언',
#   '리뷰',
#   '보고',
#   '유저',
#   '유저의견',
#   '의견',
#   '반영',
#   '메이저앱',
#   '카카오',
#   '카카오뱅크',
#   '뱅크',
#   '계좌',
#   '계좌연결',
#   '연결',
#   '비율',
#   '도'],
#  ['사용', '상담', '상담사분', '사분', '친절'],
#  ['월',
#   '구독료',
#   '고정',
#   '고정지출',
#   '지출',
#   '눈',
#   '수',
#   '적금',
#   '생각',
#   '플',
#   '플리케이션',
#   '리',
#   '케이',
#   '션',
#   '하나'],
#  ['정기',
#   '결제',
#   '건',
#   '한번',
#   '등록',
#   '얼마',
#   '신경',
#   '만',
#   '수',
#   '고정',
#   '지출',
#   '지출비가',
#   '비가',
#   '파악',
#   '월',
#   '총액',
#   '카테고리',
#   '사용',
#   '비중',
#   '등',
#   '디',
#   '디벨롭',
#   '벨롭',
#   '서비스',
#   '기대'],
#  ['가지',
#   '수정',
#   '점',
#   '개발자',
#   '무엇',
#   '구독',
#   '서비스',
#   '군데',
#   '모아',
#   '관리',
#   '수',
#   '시간',
#   '에너지',
#   '절약',
#   '도움',
#   '추',
#   '추천',
#   '천'],
#  ['통장',
#   '자동',
#   '자동결제',
#   '결제',
#   '돈',
#   '생각',
#   '나중',
#   '어플',
#   '눈',
#   '확인',
#   '가능',
#   '직관적',
#   '등록'],
#  ['나', '신경', '안', '한눈'],
#  ['반응',
#   '반응속도',
#   '속도',
#   '정기적',
#   '돈',
#   '한눈',
#   '체크',
#   '수',
#   '구독',
#   '사용',
#   '곳',
#   '지불',
#   '터',
#   '왓섭',
#   '일',
#   '거'],
#  ['구독', '서비스', '관리', '경우', '돈', '지불', '한눈', '연동', '입력', '수', '사용'],
#  ['눈',
#   '라',
#   '정기적',
#   '결제',
#   '관리',
#   '복잡',
#   '분',
#   '분안',
#   '안',
#   '연동',
#   '로딩속도',
#   '마음',
#   '생활',
#   '생활지출',
#   '지출',
#   '구독',
#   '구독서비스',
#   '서비스',
#   '가능',
#   '편리',
#   '앞',
#   '유지'],
#  ['개',
#   '구독',
#   '구독서비스',
#   '서비스',
#   '이용',
#   '분',
#   '결제',
#   '젠지',
#   '내용',
#   '수',
#   '앱',
#   '하나',
#   '알람',
#   '구',
#   '구독해지도',
#   '독해',
#   '지도',
#   '가능',
#   '편리',
#   '인증서',
#   '문제',
#   '골머리',
#   '담당자',
#   '친절',
#   '코칭',
#   '해결',
#   '분',
#   '설치',
#   '생각'],
#  ['다',
#   '간편',
#   '간편결제',
#   '결제',
#   '추가',
#   '추가여',
#   '여',
#   '휴대폰',
#   '입력',
#   '수',
#   '정기',
#   '정기결제',
#   '그것',
#   '가시',
#   '편리'],
#  ['사용',
#   '목적',
#   '분명',
#   '데',
#   '기대',
#   '앱',
#   '조',
#   '조작도',
#   '작도',
#   '간단',
#   '정확',
#   '내용',
#   '확인',
#   '수'],
#  ['요즘',
#   '여기저기',
#   '구독',
#   '관리',
#   '머리',
#   '삶',
#   '버그',
#   '문의',
#   '진행',
#   '상황',
#   '피드백',
#   '하루',
#   '수정',
#   '메',
#   '메일',
#   '일',
#   '불금',
#   '개발자',
#   '개발자분',
#   '분',
#   '야근'],
#  ['편리', '사용', '문', '사항', '답변', '친절', '대책', '해결', '처리', '감사'],
#  ['서비스',
#   '발견',
#   '플',
#   '결제',
#   '결제정보등록방법',
#   '정보',
#   '등록',
#   '방법',
#   '다양',
#   '카드사',
#   '페',
#   '페이종',
#   '이종',
#   '거',
#   '최고',
#   '앱'],
#  ['업무',
#   '업무처리속',
#   '처리',
#   '속',
#   '연휴',
#   '버그',
#   '월요일',
#   '아침',
#   '제거',
#   '결제',
#   '결제날짜',
#   '날짜',
#   '일일',
#   '일일히',
#   '히',
#   '확인',
#   '이거',
#   '체크',
#   '체크가능',
#   '가능',
#   '삶',
#   '윤택',
#   '국',
#   '국내',
#   '내',
#   '개발자',
#   '팅',
#   '개발지',
#   '개발지꿈나무',
#   '꿈나무',
#   'ㅠ'],
#  ['대체',
#   '무엇',
#   '감이',
#   '꿀',
#   '꿀가주몽',
#   '주몽',
#   '보고',
#   '설치',
#   '인증서',
#   '본인',
#   '본인인증',
#   '인증',
#   '한번',
#   '여기저기',
#   '돈',
#   '거',
#   '추가',
#   '덕분',
#   '내',
#   '월급',
#   '고정비',
#   '어디',
#   '파악',
#   '강추'],
#  ['가입',
#   '때',
#   '정보',
#   '작성',
#   '편리',
#   '생각',
#   '이것저것',
#   '구독',
#   '구독중',
#   '중',
#   '성찰',
#   '플',
#   '결제',
#   '결제방법',
#   '방법',
#   '통신사',
#   '집계',
#   '집계안',
#   '안',
#   '항목',
#   '직접',
#   '등록',
#   '사용',
#   '수'],
#  ['공동', '공동인증서', '인증서', '하나', '사용', '서비스', '반', '관리', '수', '곳', '정확'],
#  ['구독',
#   '구독서비스',
#   '서비스',
#   '페이코',
#   '이용',
#   '이용중이여',
#   '중이',
#   '여',
#   '조회',
#   '구독정보',
#   '정보',
#   '수',
#   '거',
#   '다운',
#   '페',
#   '코',
#   '연동',
#   '연동서비스',
#   '가능',
#   '지면',
#   '본격적',
#   '다크',
#   '다크모드버전',
#   '모드',
#   '버전'],
#  ['요금', '수', '앱'],
#  ['채팅',
#   '채팅상담',
#   '상담',
#   '친절',
#   '끝',
#   '끈기',
#   '문제',
#   '해결',
#   '믿음',
#   '거',
#   '기능도',
#   '편리',
#   '카카오',
#   '카카오은행',
#   '은행',
#   '페이',
#   '등록',
#   '완벽',
#   '듯'],
#  ['정기적', '지출', '돈', '한눈', '파악', '수', '해', '해지도', '지도', '왓섭', '가능', '편리', '유용'],
#  ['추후',
#   '업데이트',
#   '기대',
#   '별',
#   '별점',
#   '점',
#   '수정',
#   '구독',
#   '구독서비스',
#   '서비스',
#   '추천',
#   '추천알',
#   '알',
#   '관련',
#   '문제',
#   '피드백',
#   '갑사',
#   '평상시'],
#  ['문', '일', '뒤', '갱신', '서비스', '대신', '아이콘'],
#  ['광고',
#   '세상',
#   '정기',
#   '정기결제',
#   '결제',
#   '뿐',
#   '보험료',
#   '통신비',
#   '생활비',
#   '고정',
#   '지출',
#   '눈',
#   '위젯기능',
#   '추가'],
#  ['주거래', '계좌', '후', '자동', '자동이체', '이체', '결제', '내역', '정리', '한번', '관리'],
#  ['사용', '독', '물품', '구별', '왓섭', '물건', '구독', '간편', '이용', '설명', '거', '추천'],
#  ['정기적', '하나', '둘', '관리', '즘', '어플', '날', '지출', '지출예상', '예상', '감사'],
#  ['정기', '정기결제', '결제', '눈', '수', '비밀', '비밀번호', '번호', '문의', '친절', '해결'],
#  ['그때', '뭐', '자동', '자동이체', '이체', '생활', '때', '앱덕분', '편리'],
#  ['월별', '결제', '액', '금액', '소비', '소비계획', '계획', '상담', '친절'],
#  ['상담', '상담창구', '창구', '때', '답변', '고정', '고정지출내역', '지출', '내역', '번', '수'],
#  ['구독', '관리', '서비스', '위', '왓섭', '이거', '나', '돈', '편', 'ㅢ'],
#  ['적금', '자동', '자동이체', '이체', '도', '관리'],
#  ['디자인', '직관적', '정기', '정기지출', '지출', '목록', '한번', '수'],
#  ['카드', '연결', '시', '오류', '카톡으', '답', '해결', '친절', '저', '문의', '강추'],
#  ['진심',
#   '최고',
#   '앱이네',
#   '제가',
#   '구독',
#   '구독병',
#   '병',
#   '돈',
#   '쥐',
#   '새',
#   '올해',
#   '터',
#   '관리해야겠어',
#   '앱',
#   '큰절',
#   '한번'],
#  ['결재', '복잡', '한눈', '구', '구글', '글', '플레이', '내', '구독', '안', '수'],
#  ['구독', '관리도', '관리', '정', '정도로', '도로', '안', '유명', '정리', '거', '정성', '플'],
#  ['직관적', '느낌', '매', '사용', '때'],
#  ['구독', '서비스', '총', '합계', '합계금액', '금액', '표시'],
#  ['앱',
#   '사용',
#   '카카오',
#   '카카오뱅크',
#   '뱅크',
#   '체크',
#   '체크카드',
#   '카드',
#   '결제',
#   '구독',
#   '한시',
#   '연동',
#   '바램'],
#  ['광고', '인터페이스', '해지', '도움', '기능', '말썽', '때', '상담', '친절', '해결', '돈', '새', '거'],
#  ['구독',
#   '거',
#   '뿐',
#   '뿐안',
#   '안',
#   '돈',
#   '실',
#   '실시간',
#   '시간',
#   '수',
#   '편리',
#   '문의',
#   '친절',
#   '해결',
#   '왓섭'],
#  ['모든', '계좌', '대신', '관리', '구', '구독', '독', '서비스', '서비스라니', '라니', '참신', '앱'],
#  ['오류',
#   '고객',
#   '고객센터',
#   '센터',
#   '문의',
#   '완전',
#   '친절',
#   '답변',
#   '하나하나',
#   '정성',
#   '느낌',
#   '기분',
#   '구독',
#   '어플',
#   '관리',
#   '플',
#   '취지',
#   '만족'],
#  ['구독', '기능', '편리', '사용', '생수', '불편'],
#  ['꿀', '꿀가주몽', '주몽', '본건', '유용', '플', '번', '중복', 'ㅎ'],
#  ['수동', '불편', '불편하단', '하단', '사람', '데', '전', '자동', '눈'],
#  ['관리',
#   '독',
#   '연장',
#   '전',
#   '카카오',
#   '카카오페이',
#   '페',
#   '이',
#   '연동',
#   '대부분',
#   '카카오페이로',
#   '이로',
#   '결제',
#   '말',
#   '카카오페이도',
#   '페이도',
#   '가능',
#   '앱'],
#  ['모든앱',
#   '포함',
#   '직관적',
#   '앱',
#   '상담',
#   '친절',
#   '정기',
#   '정기결제',
#   '결제',
#   '수',
#   '편리',
#   '생각',
#   '감사',
#   '개발자',
#   '아까',
#   '제보',
#   '앱아이콘',
#   '아이콘',
#   '이번',
#   '이번주',
#   '주'],
#  ['구독',
#   '구독경제',
#   '경제',
#   '흐름',
#   '앱',
#   '개발',
#   '초기',
#   '단',
#   '단계라',
#   '계라',
#   '보완',
#   '점',
#   '여타',
#   '핀',
#   '핀테크',
#   '테크',
#   '부탁'],
#  ['최근', '통신비', '오고', '리스트', '카카오톡으', '문의', '처리', '감사'],
#  ['폰', '폰사면', '사면', '무료', '이벤트', '때문', '가입', '서비스', '관리', '됬', '데', '왓섭'],
#  ['구독', '관리', '간편', '효율적', '무엇', '문제', '발생', '때', '친절', '상담'],
#  ['구독', '관리', '관련', '문의', '친절', '응대', '무료', '수', '플'],
#  ['왓섭', '덕분', '구독', '건', '수', '결제', '계속', '얘기', '차치', '앱', '계석', '감사'],
#  ['줄',
#   '랏',
#   '데',
#   '전기세',
#   '도시',
#   '관리',
#   '관리비',
#   '비',
#   '등',
#   '생각',
#   '지출',
#   '당황',
#   '감사',
#   '사용'],
#  ['왓섭', '고정', '고정지출', '지출', '확인', '저', '감사', '응원'],
#  ['원래', '별', '별점', '점', '일', '일처리', '처리', '주심', '플', '일', '듯', '강추'],
#  ['일일', '일일히', '히', '정기', '정기결제', '결제', '확인', '편리', '거'],
#  ['자동',
#   '구독',
#   '구독중인',
#   '중인',
#   '서비스',
#   '정기',
#   '결제',
#   '결제내역',
#   '내역',
#   '를',
#   '정리',
#   '관리',
#   '수',
#   '가족',
#   '추천',
#   '생각',
#   '편리',
#   '유용'],
#  ['드로', '드로이드', '이드', '다운', '이슈', '해결', '정기', '정기결제', '결제', '관리', '앱', '왓섭'],
#  ['은행',
#   '은행연동',
#   '연동',
#   '카드',
#   '카드연동',
#   '정기',
#   '정기결제',
#   '결제',
#   '내역',
#   '개인',
#   '자산',
#   '한눈',
#   '수',
#   '현재',
#   '중인',
#   '신규',
#   '정',
#   '정기구독도',
#   '기구',
#   '독도',
#   '신청',
#   '신청가능',
#   '가능',
#   '어플',
#   '업데이트',
#   '거'],
#  ['개인적', '디자인', '디자인씽킹', '씽', '킹', '프로젝트', '아이디어', '서비스', '구현', '왓섭', '응원'],
#  ['제가', '개발', '서비스', '감사'],
#  ['카드', '등록', '구독', '서비스', '한번', '수', '정리'],
#  ['어플', '한눈', '지출', '지출관리', '관리', '수', '사용', '듯'],
#  ['소액', '소액결재', '결재', '때', '한번', '수', '추천', '추천추천'],
#  ['휴대폰', '휴대폰결제', '결제', '구독', '사용', '사용중인서비스', '중인', '서비스', '추가', '가능', '부탁'],
#  ['전', '세계', '유일', '무이', '최고', '구독', '관리', '관리앱', '앱'],
#  ['구독', '소비', '줄', '지출', '수'],
#  ['생활', '정기적', '생활지출', '지출', 'ㅎ', '관련', '관련앱', '앱', '정확'],
#  ['관리자', '피드백'],
#  ['상담', '친절', '사용'],
#  ['플', '조음'],
#  ['앱', '필요', '기능', '배치', '사용', '편리'],
#  ['스포', '스포티파이', '티', '파이', '상담', '상담요청', '요청', '연락', '친절', '원인'],
#  ['구독', '구독관리', '관리', '앱', '중', '맨트', '매력적', 'ㅎ'],
#  ['핸드폰', '핸드폰결제', '결제', '구독', '서비스', '이용', '이용중', '중', '추가'],
#  ['한눈', '수', '등록', '안', '문의'],
#  ['앞', '지출', '지출관리', '관리'],
#  ['왓섭', '제가', '서비스', '눈', '연동', '연동속', '속'],
#  ['구독', '거', '한번', '수', '친절', '상담'],
#  ['불필요', '지출', '관리', '개인', '금융', '매니저', '추천'],
#  ['덕분', '무료', '구독', '돈', '나', '거', '해지', '줄'],
#  ['응답', '자세', '설명', '친절', '안내'],
#  ['여기저기',
#   '가입',
#   '정기',
#   '정기요금',
#   '요금',
#   '돈',
#   '얼마',
#   '이',
#   '플',
#   '덕분',
#   '이용',
#   '앞',
#   '운영'],
#  ['상담원', '상담원분', '분', '친절', '앱', '사용'],
#  ['구독', '돈', '확인', '확인가능', '가능', '거랑'],
#  ['상담', '상담시', '시', '친절', '대응', '감사', '기능도'],
#  ['덕분', '저', '돈', '수', '앞'],
#  ['정확', '사', '사용도', '용도'],
#  ['감사',
#   '영어',
#   '영어회화',
#   '회화',
#   '정기',
#   '정기구독서비스',
#   '구독',
#   '서비스',
#   '카드',
#   '카드결제',
#   '결제',
#   '해지',
#   '해지방법',
#   '방법',
#   '중',
#   '인터넷',
#   '검색',
#   '카드금융결제',
#   '금융',
#   '관리',
#   '왓섭',
#   '가입',
#   '자세',
#   '친절',
#   '담당',
#   '담당직원분',
#   '직원',
#   '분',
#   '해결',
#   '마음',
#   '최'],
#  ['지출', '지출내역등', '내역', '등', '관리', '한번', '수'],
#  ['왓섭', '진짜', '추천', '최'],
#  ['자동'],
#  ['완전', '정', '정기구독', '기구', '독', '관리', '제가', '이래', '마니', '잇', '다'],
#  ['구독', '서비스', '관리', '한번', '편리'],
#  ['친절',
#   '등록',
#   '부분',
#   '카톡플친으',
#   '안내',
#   '근무',
#   '근무시간',
#   '시간',
#   '문의',
#   '처음',
#   '끝',
#   '친구',
#   '대화',
#   '해결',
#   '앱',
#   '애정',
#   '앞'],
#  ['돈', '중'],
#  ['카카오',
#   '카카오뱅크',
#   '뱅크',
#   '등록',
#   '정',
#   '정보도',
#   '보도',
#   '공유',
#   '처리',
#   '과정',
#   '메일',
#   '설치',
#   '중이',
#   '담당자',
#   '감이'],
#  ['넷',
#   '넷플릭스',
#   '플릭스',
#   '핸드폰',
#   '핸드폰요금',
#   '요금',
#   '내일',
#   '거',
#   '확인',
#   '입금',
#   'ㄷ',
#   'ㄷㄷ',
#   '요건'],
#  ['대응', '한눈', '수', '편리'],
#  ['인터페이스'],
#  ['요즘', '시대', '필요', '신', '신박', '박', '앱', '정리', '정리앱', '사용', '추천'],
#  ['정기', '정기적인지출', '적인', '지출', '사용'],
#  ['다양', '지출', '지출내역', '내역'],
#  ['편리', '유용', '플', '도움'],
#  ['구독', '구독형', '형', '서비스', '한눈', '수'],
#  ['카드',
#   '카드연동만',
#   '연',
#   '동만',
#   '정기',
#   '정기결제',
#   '결제',
#   '리스',
#   '리스팅',
#   '팅',
#   '넷플릭스',
#   '애플',
#   '애플뮤직',
#   '뮤직',
#   '앞',
#   '왓섭으',
#   '관리'],
#  ['사용', '편리', '앱들'],
#  ['관리', '수'],
#  ['별', '생각', '거', 'ㅎ', '돈', '관리', '분', '추천'],
#  ['오', '이거', '내', '돈', '한눈'],
#  ['앱'],
#  ['리뷰', '엡이'],
#  ['심플', '사용자', '편의', '고려', '진', '구독', '구독서비스앱', '서비스', '앱'],
#  ['정보', '수', '고객', '고객센터', '센터', '문의', '문의내용', '내용', '대응'],
#  ['생각', '전', '만족'],
#  ['완전', '돈', '관리', '시간', '절약되'],
#  ['눈', '나의', '지출', '확인', '수'],
#  ['내', '돈', '심플', '확인', '수', '츈'],
#  ['여태',
#   '구독',
#   '구독서비스',
#   '서비스',
#   '이용',
#   '이거',
#   '첨',
#   '덕뷴',
#   '월',
#   '만원',
#   '듯',
#   'ㄱ',
#   'ㄱㅅ합미',
#   'ㅅ',
#   '합',
#   '미'],
#  ['우리집', '돈', '돈관리', '관리', '와이프', '가계부', '정리'],
#  ['한눈', '파악', '너', '뮤', '편'],
#  ['카톡으', '응대', '감동', '였음앱자체', '대만족'],
#  ['동생'],
#  ['편리', '사용'],
#  [],
#  ['고객', '고객센터', '센터', '응대', '친절'],
#  ['플', '감사'],
#  ['친절', '편리햐'],
#  ['해킹', '해킹위협', '위협', '감지', '실행', '가요'],
#  ['편리'],
#  ['무엇', '구독', '눈', '수'],
#  ['그동안', '필요', '서비스', '감사'],
#  [],
#  ['요즘', '구독', '구독서비스', '서비스', '사용', '관리'],
#  ['상담',
#   '친절',
#   '플랫폼',
#   '유일',
#   '무이',
#   '처음',
#   '플',
#   '리뷰',
#   '구독',
#   '구독서비스',
#   '서비스',
#   '세상',
#   '소비자',
#   '입장',
#   '유용',
#   '데',
#   '수백',
#   '수백개',
#   '개',
#   '중',
#   '만족',
#   '대만족',
#   '다',
#   '번창',
#   '번창하세',
#   '하세',
#   '진심'],
#  ['연동', '아이디', '비밀', '비밀번호', '번호', '입력', '은행', '정보', '개인', '개인정보', '유출', '우려'],
#  ['앱이네', '거', 'ㅎ'],
#  ['구독', '구독서비스', '서비스', '철야', '야근', '롱런'],
#  ['경상', '경상북도', '북도'],
#  ['간편', '간편결제서비스', '결제', '서비스'],
#  ['대박', '이것'],
#  ['음', '세상', '편리'],
#  ['최고', '말'],
#  ['넘', '유용'],
#  ['어플이네'],
#  ['적금', '청약'],
#  ['완전', '도움되'],
#  ['편리', '어플같아'],
#  ['저', '돈', '관리'],
#  [],
#  ['얼마'],
#  ['친구', '보험료', '적금', '아파트', '아파트관리비등', '관리비', '등', '눈', '관리'],
#  ['편리', '상담', '상담사', '사', '겁', '친절', '친절하심', '하심'],
#  ['사용', '간편', '추천'],
#  ['친절', '안내', '감사'],
#  ['처음', '유용'],
#  ['오', '생활', '도움'],
#  ['생활', '생활편의', '편의', '유용', '앱'],
#  ['한번', '정리', '친절', '상담'],
#  ['기능', '기능설명란', '설', '명란', '개발', '개발팀', '팀', '디자인', '디자인팀', '설명', '커여워', '점'],
#  ['편리'],
#  ['추천'],
#  ['비용', '절감'],
#  ['카카오', '카카오뱅크', '뱅크', '때', '숨'],
#  [],
#  ['욯'],
#  ['뱅샐', '왓섭으'],
#  ['친절', '고객', '고객상담', '상담'],
#  ['서비스'],
#  [],
#  [],
#  ['재테크', '필수', '필수앱', '앱', '왓'],
#  ['고객', '의', '자산', '관리', '왓섭으', '안내', '정도', '완벽', '플'],
#  ['저', '앞자리', '왓섭대표'],
#  ['굿', '이거'],
#  ['신세계'],
#  ['뱅샐', '굿'],
#  ['꿀', '꿀가주몽', '주몽'],
#  ['내', '인생'],
#  [],
#  [],
#  [],
#  ['친절'],
#  [],
#  ['짱']]

# %%
processed_data=data_word
num_topics = 3
chunksize = 300
passes = 20
iterations = 2
eval_every = None
dictionary = corpora.Dictionary(processed_data)
temp = dictionary[0]
id2word = dictionary.id2token

model = LdaModel(
    corpus=corpus,
    id2word=id2word,
    chunksize=chunksize,
    alpha='auto',
    eta='auto',
    iterations=iterations,
    num_topics=num_topics,
    passes=passes,
    eval_every=eval_every
)

# %%
lda_visualization = gensimvis.prepare(model, corpus, dictionary, sort_topics=False)
pyLDAvis.save_html(lda_visualization, 'file_name_5.html')

# %%
#pip install pyLDAvis
